# %% [markdown]
# <a href="https://colab.research.google.com/github/sapnasingh4852-source/python-DATA-science/blob/main/lec03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fun_name(parameters):
#body of the function

# %%
def add_numbers(num1, num2):
    return num1 + num2

# Example usage:
result = add_numbers(6, 7)
print(result)
# Out:
# 13

# %%
#lambda function
x = lambda a, b: b * a
print(x(2,3))
# Out:
# 6

# %%
st = " "
print(len(st))

st = "anand"
st1 = st.upper()
print(st1)
# Out:
# 1
# ANAND

# %%
# change case  :  lower(),upper(),title(),capitalize()


st = "SAPNA"
st1 = st.lower()
print (st1)


st2 = "sapna"
st2 = st.upper()
print (st2)


st3 = "sapna singh"
st3 = st.title()
print (st3)


st4 = "sapna singh"
st4 = st.capitalize()
print (st4)
# Out:
# sapna
# SAPNA
# Sapna
# Sapna

# %%
first_name  = '  Sapna '
last_name = 'Singh'

first_name = first_name.strip()
last_name = last_name.strip()

full_name = first_name + last_name
print(full_name)
# Out:
# SapnaSingh

# %%
a = " today "
b = " weather"
c = "is GOOD"

A = a.capitalize()
B = b . lower()
C = c. lower()


ans =  print(( A + ' ' + B + ' ' + C).capitalize())
# Out:
#  today   weather is good

# %%
st = " today weather is good "
st.replace("good","bad")
# Out:
# ' today weather is bad '

# %%
st = "today weather is good"
ans = st.find("is")
print(ans)
# Out:
# 14

# %%
st = "Today weather is good "
st1 = st.startswith("today")
print(st1)
st2 = st.startswith("Today")
print(st2)
# Out:
# False
# True

# %%
dct = {
    "name":"ramesh",
    "age":23,
    "occupation":"student",
    "class":10,
    "roll no" : 25
}
